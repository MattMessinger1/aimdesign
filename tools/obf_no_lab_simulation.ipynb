# %% [markdown]
# # OBF no-lab screening simulation\n\nThis notebook is intended as a **non-qualifying screening tool** to prioritize formulations and identify high-leverage knobs before physical builds.\n
